# %%
# %load_ext autoreload
# %autoreload 2

import copy
import pandas as pd
from src.bot.util.features import *
from src.bot.util.data import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tournaments = [
    'games/final/'
]

num_games = 0
max_games = 0

player = GamePlayer()
player.filter_seats(lambda x: x['private_bot_top'])

for tournament_dir in tournaments:
    for game in get_games(tournament_dir, player_names=["dannyace", "KillFish", "fcll"]):
        if (max_games == 0) or (num_games < max_games):
            player.play_game(game)
            num_games += 1
        else:
            break

    print('Tournament: ' + tournament_dir + ' Games: ' + str(num_games))

X, y = player.get_features()
X.to_pickle('data/X_final.pickle')
y.to_pickle('data/y_final.pickle')

y.head()
# Out:
# 10000 {'jpbcxvfepxffdzesdngbde': {'private_game_num': 116, 'private_game_win': False, 'private_game_end_stack': 1225, 'private_bot_name': 'fcll', 'private_bot_top': True, 'small_blind_amount': 15, 'initial_stack': 1500, 'total_stack': 13500, 'players': {'vqdivsngukjsdppvmhudsy': {'me': False, 'num': 0, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1500, 'start_stack': 1500, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 4, 'fold_in_round': 1, 'fold_in_street': 0, 'fold_in_preflop': 1, 'fold_preflops': 4, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 4, 'flop_rounds': 0, 'flop_actions': 0, 'turn_rounds': 0, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'folded'}, 'jpbcxvfepxffdzesdngbde': {'me': True, 'num': 1, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 1, 'win_rounds_nohand': 0, 'stack': 1380, 'start_stack': 1410, 'hand_paid': 30, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 13, 'fold_rounds': 2, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 1, 'fold_in_flop': 0, 'fold_flops': 1, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 4, 'call_in_round': 1, 'call_in_street': 0, 'call_in_preflop': 1, 'call_preflops': 4, 'call_in_flop': 0, 'call_flops': 1, 'call_in_turn': 0, 'call_turns': 1, 'call_in_river': 0, 'call_rivers': 1, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 5, 'flop_rounds': 4, 'flop_actions': 2, 'turn_rounds': 2, 'turn_actions': 1, 'river_rounds': 1, 'river_actions': 1, 'state': 'participating'}, 'jlrcdnkmevixgnlwgynmqe': {'me': False, 'num': 2, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 2, 'lose_rounds': 1, 'win_rounds_nohand': 0, 'stack': 1590, 'start_stack': 1620, 'hand_paid': 30, 'hand_strength': 'ONEPAIR', 'hand_hole_pairs': 0, 'hand_hole_high': 12, 'fold_rounds': 0, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 0, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 3, 'call_in_round': 1, 'call_in_street': 0, 'call_in_preflop': 1, 'call_preflops': 3, 'call_in_flop': 0, 'call_flops': 1, 'call_in_turn': 0, 'call_turns': 1, 'call_in_river': 0, 'call_rivers': 1, 'raise_rounds': 2, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 1, 'raise_in_flop': 0, 'raise_flops': 1, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 4, 'flop_rounds': 4, 'flop_actions': 2, 'turn_rounds': 2, 'turn_actions': 1, 'river_rounds': 1, 'river_actions': 1, 'state': 'participating'}, 'rdgvbhnqdymfjgbrkssign': {'me': False, 'num': 3, 'dealer': 1, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 1, 'lose_rounds': 0, 'win_rounds_nohand': 1, 'stack': 1560, 'start_stack': 1560, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 3, 'fold_in_round': 1, 'fold_in_street': 0, 'fold_in_preflop': 1, 'fold_preflops': 2, 'fold_in_flop': 0, 'fold_flops': 1, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'c ...
# 20000 {'hitywjfxptvejnunmpbpax': {'private_game_num': 237, 'private_game_win': False, 'private_game_end_stack': 2832, 'private_bot_name': 'fcll', 'private_bot_top': True, 'small_blind_amount': 15, 'initial_stack': 1500, 'total_stack': 13500, 'players': {'mepfgiweunhsduptijxkdn': {'me': False, 'num': 0, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1365, 'start_stack': 1365, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 23, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 23, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 23, 'flop_rounds': 11, 'flop_actions': 0, 'turn_rounds': 0, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'participating'}, 'ypzrdqljbcsuukaviihzie': {'me': False, 'num': 1, 'dealer': 1, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1350, 'start_stack': 1350, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 23, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 23, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 23, 'flop_rounds': 8, 'flop_actions': 0, 'turn_rounds': 0, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'participating'}, 'tzqrhkpajzttsvpbotwqem': {'me': False, 'num': 2, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 1, 'lose_rounds': 4, 'win_rounds_nohand': 0, 'stack': 0, 'start_stack': 0, 'hand_paid': 637, 'hand_strength': 'TWOPAIR', 'hand_hole_pairs': 0, 'hand_hole_high': 12, 'fold_rounds': 2, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 2, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 5, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 5, 'call_in_flop': 0, 'call_flops': 4, 'call_in_turn': 0, 'call_turns': 4, 'call_in_river': 0, 'call_rivers': 3, 'raise_rounds': 2, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 1, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 1, 'preflop_actions': 8, 'flop_rounds': 5, 'flop_actions': 6, 'turn_rounds': 5, 'turn_actions': 5, 'river_rounds': 4, 'river_actions': 5, 'state': 'folded'}, 'obfhforugospggzmvouuup': {'me': False, 'num': 3, 'dealer': 0, 'small_blind': 1, 'big_blind': 0, 'win_rounds': 3, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1575, 'start_stack': 1590, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 20, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 19, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 1, 'fold_in_river': 0, 'fold_rivers': 0, ...
# 30000 {'cmgqixsysdileeohjtesad': {'private_game_num': 369, 'private_game_win': True, 'private_game_end_stack': 2400, 'private_bot_name': 'KillFish', 'private_bot_top': True, 'small_blind_amount': 15, 'initial_stack': 1500, 'total_stack': 13500, 'players': {'ngtjptzwdtstyceqnlnuty': {'me': False, 'num': 0, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 13, 'lose_rounds': 4, 'win_rounds_nohand': 6, 'stack': 1755, 'start_stack': 1785, 'hand_paid': 30, 'hand_strength': 'TWOPAIR', 'hand_hole_pairs': 0, 'hand_hole_high': 10, 'fold_rounds': 20, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 12, 'fold_in_flop': 0, 'fold_flops': 4, 'fold_in_turn': 0, 'fold_turns': 2, 'fold_in_river': 0, 'fold_rivers': 2, 'call_rounds': 32, 'call_in_round': 2, 'call_in_street': 1, 'call_in_preflop': 1, 'call_preflops': 30, 'call_in_flop': 1, 'call_flops': 17, 'call_in_turn': 0, 'call_turns': 13, 'call_in_river': 0, 'call_rivers': 10, 'raise_rounds': 9, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 2, 'raise_in_flop': 0, 'raise_flops': 4, 'raise_in_turn': 0, 'raise_turns': 3, 'raise_in_river': 0, 'raise_rivers': 1, 'preflop_actions': 44, 'flop_rounds': 29, 'flop_actions': 25, 'turn_rounds': 21, 'turn_actions': 18, 'river_rounds': 16, 'river_actions': 13, 'state': 'participating'}, 'cmgqixsysdileeohjtesad': {'me': True, 'num': 1, 'dealer': 1, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 7, 'lose_rounds': 5, 'win_rounds_nohand': 2, 'stack': 2250, 'start_stack': 2280, 'hand_paid': 30, 'hand_strength': 'ONEPAIR', 'hand_hole_pairs': 0, 'hand_hole_high': 14, 'fold_rounds': 25, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 23, 'fold_in_flop': 0, 'fold_flops': 2, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 19, 'call_in_round': 1, 'call_in_street': 0, 'call_in_preflop': 1, 'call_preflops': 19, 'call_in_flop': 0, 'call_flops': 10, 'call_in_turn': 0, 'call_turns': 8, 'call_in_river': 0, 'call_rivers': 7, 'raise_rounds': 5, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 2, 'raise_in_turn': 0, 'raise_turns': 2, 'raise_in_river': 0, 'raise_rivers': 1, 'preflop_actions': 44, 'flop_rounds': 38, 'flop_actions': 14, 'turn_rounds': 22, 'turn_actions': 10, 'river_rounds': 16, 'river_actions': 8, 'state': 'participating'}, 'rrdpqpbiayrnfdxkqnbkey': {'me': False, 'num': 2, 'dealer': 0, 'small_blind': 1, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1275, 'start_stack': 1290, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 38, 'fold_in_round': 1, 'fold_in_street': 0, 'fold_in_preflop': 1, 'fold_preflops': 38, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 38, 'flop_rounds': 28, 'flop_actions': 0, 'turn_rounds': 8, 'turn_actions': 0, 'river_rounds': 6, 'river_actions': 0, 'state': 'folded'}, 'cuxyzecennckedvyzgunio': {'me': False, 'num': 3, 'dealer': 0, 'small_blind': 0, 'big_blind': 1, 'win_rounds': 2, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1470, 'start_stack': 1500, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 36, 'fold_in_round': 1, 'fold_in_street': 0, 'fold_in_preflop': 1, 'fold_preflops': 36, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_ ...
# 40000 {'jvrncxldgfaztixnmmdknt': {'private_game_num': 485, 'private_game_win': False, 'private_game_end_stack': 2925, 'private_bot_name': 'dannyace', 'private_bot_top': True, 'small_blind_amount': 15, 'initial_stack': 1500, 'total_stack': 13500, 'players': {'zpxfyryzhsjwreptnufnrk': {'me': False, 'num': 0, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 1, 'win_rounds_nohand': 0, 'stack': 0, 'start_stack': 0, 'hand_paid': 60, 'hand_strength': 'THREECARD', 'hand_hole_pairs': 6, 'hand_hole_high': 6, 'fold_rounds': 13, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 13, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 1, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 1, 'raise_in_flop': 0, 'raise_flops': 1, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 14, 'flop_rounds': 4, 'flop_actions': 1, 'turn_rounds': 1, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'folded'}, 'jvrncxldgfaztixnmmdknt': {'me': True, 'num': 1, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 7, 'lose_rounds': 0, 'win_rounds_nohand': 2, 'stack': 2940, 'start_stack': 2940, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 33, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 32, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 1, 'call_rounds': 5, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 5, 'call_in_flop': 0, 'call_flops': 3, 'call_in_turn': 0, 'call_turns': 2, 'call_in_river': 0, 'call_rivers': 2, 'raise_rounds': 6, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 5, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 1, 'raise_in_river': 0, 'raise_rivers': 1, 'preflop_actions': 42, 'flop_rounds': 40, 'flop_actions': 3, 'turn_rounds': 9, 'turn_actions': 3, 'river_rounds': 5, 'river_actions': 4, 'state': 'participating'}, 'brsdraibaavcpscrkzzfqi': {'me': False, 'num': 2, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 6, 'lose_rounds': 0, 'win_rounds_nohand': 1, 'stack': 3015, 'start_stack': 3015, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 34, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 34, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 6, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 6, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 40, 'flop_rounds': 35, 'flop_actions': 0, 'turn_rounds': 5, 'turn_actions': 0, 'river_rounds': 2, 'river_actions': 0, 'state': 'participating'}, 'naoskvaugljbuyvyvyrfhp': {'me': False, 'num': 3, 'dealer': 1, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 15, 'lose_rounds': 1, 'win_rounds_nohand': 0, 'stack': 1290, 'start_stack': 1290, 'hand_paid': 30, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 13, 'fold_rounds': 24, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 17, 'fold_in_flop': 0, 'fold_flops': 4, 'fold_in_turn': 0, 'fold_turns': 3, 'fold_in_river': 0, 'fold_r ...
# 50000 {'bpunbhuglsvyskryekjzlu': {'private_game_num': 596, 'private_game_win': True, 'private_game_end_stack': 6330, 'private_bot_name': 'fcll', 'private_bot_top': True, 'small_blind_amount': 15, 'initial_stack': 1500, 'total_stack': 13500, 'players': {'meexnefrafksroebudqgnl': {'me': False, 'num': 0, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 2, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1440, 'start_stack': 1440, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 27, 'fold_in_round': 1, 'fold_in_street': 1, 'fold_in_preflop': 1, 'fold_preflops': 27, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 2, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 2, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 29, 'flop_rounds': 22, 'flop_actions': 0, 'turn_rounds': 2, 'turn_actions': 0, 'river_rounds': 1, 'river_actions': 0, 'state': 'folded'}, 'iclhxtxqvmotyqaznwhftg': {'me': False, 'num': 1, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 1, 'win_rounds_nohand': 0, 'stack': 0, 'start_stack': 0, 'hand_paid': 1485, 'hand_strength': 'ONEPAIR', 'hand_hole_pairs': 0, 'hand_hole_high': 13, 'fold_rounds': 8, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 8, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 1, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 1, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 9, 'flop_rounds': 6, 'flop_actions': 0, 'turn_rounds': 1, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'folded'}, 'jqsvjqbkwvfilqihlpqgle': {'me': False, 'num': 2, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 4, 'lose_rounds': 0, 'win_rounds_nohand': 1, 'stack': 2925, 'start_stack': 2925, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 25, 'fold_in_round': 1, 'fold_in_street': 1, 'fold_in_preflop': 1, 'fold_preflops': 25, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 5, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 5, 'raise_in_flop': 0, 'raise_flops': 1, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 30, 'flop_rounds': 18, 'flop_actions': 1, 'turn_rounds': 2, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'folded'}, 'pqdtxwgyhecuwugpnxjyfb': {'me': False, 'num': 3, 'dealer': 1, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 6, 'lose_rounds': 0, 'win_rounds_nohand': 1, 'stack': 3105, 'start_stack': 3135, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 22, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 15, 'fold_in_flop': 0, 'fold_flops': 5, 'fold_in_turn': 0, 'fold_turns': 1, 'fold_in_river': 0, 'fold_rivers': 1, 'call_rounds ...
# 60000 {'vmsjbbcnjwwtjgklaedhye': {'private_game_num': 724, 'private_game_win': False, 'private_game_end_stack': 0, 'private_bot_name': 'KillFish', 'private_bot_top': True, 'small_blind_amount': 15, 'initial_stack': 1500, 'total_stack': 13500, 'players': {'fvhnefdkqvpsanciovemvq': {'me': False, 'num': 0, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 2, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1800, 'start_stack': 1800, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 2, 'fold_in_round': 1, 'fold_in_street': 1, 'fold_in_preflop': 1, 'fold_preflops': 2, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 2, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 2, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 4, 'flop_rounds': 2, 'flop_actions': 0, 'turn_rounds': 0, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'folded'}, 'mxtbrpyqgjunbdqybdtdkk': {'me': False, 'num': 1, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1485, 'start_stack': 1485, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 4, 'fold_in_round': 1, 'fold_in_street': 1, 'fold_in_preflop': 1, 'fold_preflops': 4, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 4, 'flop_rounds': 0, 'flop_actions': 0, 'turn_rounds': 0, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'folded'}, 'dbetlwougzmqmpbekmkank': {'me': False, 'num': 2, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1455, 'start_stack': 1455, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 4, 'fold_in_round': 1, 'fold_in_street': 1, 'fold_in_preflop': 1, 'fold_preflops': 4, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 4, 'flop_rounds': 0, 'flop_actions': 0, 'turn_rounds': 0, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'folded'}, 'vmsjbbcnjwwtjgklaedhye': {'me': True, 'num': 3, 'dealer': 1, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1380, 'start_stack': 1380, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 3, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 2, 'fold_in_flop': 0, 'fold_flops': 1, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 2,  ...
# 70000 {'cdjiqkrsrcdlzargmpkozq': {'private_game_num': 841, 'private_game_win': False, 'private_game_end_stack': 0, 'private_bot_name': 'fcll', 'private_bot_top': True, 'small_blind_amount': 15, 'initial_stack': 1500, 'total_stack': 13500, 'players': {'yiunvhjximdckevstukuuq': {'me': False, 'num': 0, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1455, 'start_stack': 1455, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 10, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 10, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 10, 'flop_rounds': 5, 'flop_actions': 0, 'turn_rounds': 0, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'participating'}, 'ivjbydsypyazsuperzkefy': {'me': False, 'num': 1, 'dealer': 1, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 1, 'win_rounds_nohand': 0, 'stack': 1335, 'start_stack': 1335, 'hand_paid': 30, 'hand_strength': 'ONEPAIR', 'hand_hole_pairs': 0, 'hand_hole_high': 6, 'fold_rounds': 9, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 7, 'fold_in_flop': 0, 'fold_flops': 1, 'fold_in_turn': 0, 'fold_turns': 1, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 4, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 4, 'call_in_flop': 0, 'call_flops': 2, 'call_in_turn': 0, 'call_turns': 1, 'call_in_river': 0, 'call_rivers': 1, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 11, 'flop_rounds': 5, 'flop_actions': 3, 'turn_rounds': 3, 'turn_actions': 2, 'river_rounds': 2, 'river_actions': 1, 'state': 'participating'}, 'wuvqwhiphdgkokyisgfoqn': {'me': False, 'num': 2, 'dealer': 0, 'small_blind': 1, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1410, 'start_stack': 1425, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 10, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 10, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 10, 'flop_rounds': 4, 'flop_actions': 0, 'turn_rounds': 0, 'turn_actions': 0, 'river_rounds': 0, 'river_actions': 0, 'state': 'participating'}, 'ytztdgyllbhwckorsdhqgm': {'me': False, 'num': 3, 'dealer': 0, 'small_blind': 0, 'big_blind': 1, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1425, 'start_stack': 1455, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 10, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 10, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_riv ...
# 80000 {'ubpvgifshjhluocpgiqkdm': {'private_game_num': 959, 'private_game_win': False, 'private_game_end_stack': 0, 'private_bot_name': 'KillFish', 'private_bot_top': True, 'small_blind_amount': 15, 'initial_stack': 1500, 'total_stack': 13500, 'players': {'ouldqesfuhejjyhtlyiomt': {'me': False, 'num': 0, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1500, 'start_stack': 1500, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 7, 'fold_in_round': 1, 'fold_in_street': 0, 'fold_in_preflop': 1, 'fold_preflops': 7, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 7, 'flop_rounds': 6, 'flop_actions': 0, 'turn_rounds': 2, 'turn_actions': 0, 'river_rounds': 2, 'river_actions': 0, 'state': 'folded'}, 'kmtljqzxigmbtjpgfxdiru': {'me': False, 'num': 1, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1485, 'start_stack': 1485, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 7, 'fold_in_round': 1, 'fold_in_street': 0, 'fold_in_preflop': 1, 'fold_preflops': 7, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 7, 'flop_rounds': 6, 'flop_actions': 0, 'turn_rounds': 2, 'turn_actions': 0, 'river_rounds': 2, 'river_actions': 0, 'state': 'folded'}, 'uurfwozthmlwkniugpdbud': {'me': False, 'num': 2, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 1, 'lose_rounds': 2, 'win_rounds_nohand': 1, 'stack': 1410, 'start_stack': 1440, 'hand_paid': 30, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 14, 'fold_rounds': 3, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 2, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 1, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 5, 'call_in_round': 1, 'call_in_street': 0, 'call_in_preflop': 1, 'call_preflops': 5, 'call_in_flop': 0, 'call_flops': 4, 'call_in_turn': 0, 'call_turns': 4, 'call_in_river': 0, 'call_rivers': 3, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 7, 'flop_rounds': 7, 'flop_actions': 4, 'turn_rounds': 4, 'turn_actions': 5, 'river_rounds': 4, 'river_actions': 4, 'state': 'participating'}, 'hsmzebpkcvzfallusnvcjl': {'me': False, 'num': 3, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 1, 'win_rounds_nohand': 0, 'stack': 1455, 'start_stack': 1455, 'hand_paid': 30, 'hand_strength': 'TWOPAIR', 'hand_hole_pairs': 0, 'hand_hole_high': 12, 'fold_rounds': 6, 'fold_in_round': 1, 'fold_in_street': 0, 'fold_in_preflop': 1, 'fold_preflops': 6, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_r ...
# 90000 {'dxqpitmewsfjmejwrdjewu': {'private_game_num': 1055, 'private_game_win': False, 'private_game_end_stack': 2227, 'private_bot_name': 'KillFish', 'private_bot_top': True, 'small_blind_amount': 15, 'initial_stack': 1500, 'total_stack': 13500, 'players': {'itokfwwoffowwtcblbegel': {'me': False, 'num': 0, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 0, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1275, 'start_stack': 1275, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 43, 'fold_in_round': 1, 'fold_in_street': 1, 'fold_in_preflop': 1, 'fold_preflops': 43, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 0, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 0, 'call_in_flop': 0, 'call_flops': 0, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 0, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 0, 'raise_in_turn': 0, 'raise_turns': 0, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 43, 'flop_rounds': 28, 'flop_actions': 0, 'turn_rounds': 3, 'turn_actions': 0, 'river_rounds': 1, 'river_actions': 0, 'state': 'folded'}, 'wseoyqtmwyzpeiiezljnsl': {'me': False, 'num': 1, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 3, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1530, 'start_stack': 1530, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 40, 'fold_in_round': 1, 'fold_in_street': 1, 'fold_in_preflop': 1, 'fold_preflops': 40, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 5, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 5, 'call_in_flop': 0, 'call_flops': 1, 'call_in_turn': 0, 'call_turns': 0, 'call_in_river': 0, 'call_rivers': 0, 'raise_rounds': 3, 'raise_in_round': 0, 'raise_in_street': 0, 'raise_in_preflop': 0, 'raise_preflops': 0, 'raise_in_flop': 0, 'raise_flops': 2, 'raise_in_turn': 0, 'raise_turns': 1, 'raise_in_river': 0, 'raise_rivers': 0, 'preflop_actions': 46, 'flop_rounds': 23, 'flop_actions': 3, 'turn_rounds': 3, 'turn_actions': 1, 'river_rounds': 1, 'river_actions': 0, 'state': 'folded'}, 'ujsdilkdbeirrrxieqxvwc': {'me': False, 'num': 2, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 24, 'lose_rounds': 6, 'win_rounds_nohand': 3, 'stack': 3809, 'start_stack': 4394, 'hand_paid': 150, 'hand_strength': 'THREECARD', 'hand_hole_pairs': 0, 'hand_hole_high': 13, 'fold_rounds': 12, 'fold_in_round': 0, 'fold_in_street': 0, 'fold_in_preflop': 0, 'fold_preflops': 9, 'fold_in_flop': 0, 'fold_flops': 2, 'fold_in_turn': 0, 'fold_turns': 1, 'fold_in_river': 0, 'fold_rivers': 0, 'call_rounds': 11, 'call_in_round': 0, 'call_in_street': 0, 'call_in_preflop': 0, 'call_preflops': 1, 'call_in_flop': 0, 'call_flops': 10, 'call_in_turn': 0, 'call_turns': 8, 'call_in_river': 0, 'call_rivers': 6, 'raise_rounds': 39, 'raise_in_round': 1, 'raise_in_street': 1, 'raise_in_preflop': 1, 'raise_preflops': 39, 'raise_in_flop': 0, 'raise_flops': 2, 'raise_in_turn': 0, 'raise_turns': 1, 'raise_in_river': 0, 'raise_rivers': 2, 'preflop_actions': 49, 'flop_rounds': 41, 'flop_actions': 14, 'turn_rounds': 14, 'turn_actions': 10, 'river_rounds': 10, 'river_actions': 8, 'state': 'participating'}, 'svyasbexuxybqfjdxfxbvo': {'me': False, 'num': 3, 'dealer': 0, 'small_blind': 0, 'big_blind': 0, 'win_rounds': 5, 'lose_rounds': 0, 'win_rounds_nohand': 0, 'stack': 1980, 'start_stack': 1980, 'hand_paid': 0, 'hand_strength': 'HIGHCARD', 'hand_hole_pairs': 0, 'hand_hole_high': 0, 'fold_rounds': 38, 'fold_in_round': 1, 'fold_in_street': 1, 'fold_in_preflop': 1, 'fold_preflops': 38, 'fold_in_flop': 0, 'fold_flops': 0, 'fold_in_turn': 0, 'fold_turns': 0, 'fold_in_river': 0 ...
# Tournament: games/final/ Games: 1133
#    private_best_hand private_bot_action  private_bot_action_amount  \
# 0                 -1               CALL                          2
# 1                 -1              RAISE                          2
# 2                 -1               FOLD                          0
# 3                 -1               CALL                          2
# 4                  1              RAISE                          3
#
#   private_bot_name  private_bot_top private_community_card  \
# 0             fcll             True   [HT, HK, S9, D6, DJ]
# 1             fcll             True   [HT, HK, S9, D6, DJ]
# 2             fcll             True   [HT, HK, S9, D6, DJ]
# 3             fcll             True   [S4, H2, S7, D4, H3]
# 4             fcll             True   [S4, H2, S7, D4, H3]
#
#    private_game_end_stack  private_game_num  private_game_win  \
# 0                     170                 0             False
# 1                     170                 0             False
# 2                     170                 0             False
# 3                     170                 0             False
# 4                     170                 0             False
#
#   private_hole_card private_opponent_hole_card  private_round_end  \
# 0          [C7, S4]                 [[DT, H9]]              False
# 1          [C7, S4]                 [[DT, H9]]              False
# 2          [C7, S4]                 [[DT, H9]]              False
# 3          [HQ, S3]       [[C5, SK], [CK, C3]]              False
# 4          [HQ, S3]                 [[C5, SK]]              False
#
#    private_round_end_stack  private_round_end_stack_diff
# 0                       97                            -3
# 1                       97                            -3
# 2                       97                            -3
# 3                       92                            -5
# 4                       92                            -5
